# %% [markdown]
# # 10번.

# %% [markdown]
# ## Step1. 데이터 불러오기

# %%
# Boston housing data set을 불러온다.
from sklearn.datasets import load_boston
housing_data = load_boston()

import pandas as pd
x = load_boston().data
Boston = pd.DataFrame(x,columns = housing_data['feature_names'])
Boston['MEDV']=housing_data.target
Boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %% [markdown]
# ### a번 문제. data set의 row 및 columns의 수와 row 및 columns가 각각 의미하는 바는?

# %%
print('a번 정답')
print('1. row 수는',Boston.shape[0],'이며 이는 observation, 즉 보스턴의 town 수 이다.')
print('2. columns 수는',Boston.shape[1],'이며 이는 각 집의 특징이다.')
DECR = ['자치시별 1인당 범죄율','25,000 평방피트를 초과하는 거주지역의 비율','비소매상업지역이 점유하고 있는 토지의 비율',
       '찰스강에 대한 더미변수(강의 경계에 위치하면 1, 아니면 0)','10ppm당 농축 일산화질소','주태 1가구당 평균 방 개수',
       '1940년 이전에 건축된 소유주택의 비율','5개의보스턴 직업센터까지의 접근성 지수','방사형 도로까지의 접근성 지수',
       '10,000 달러 당 재산 세율','자치시별 학생/교사 비율','1000(Bk-0.63)^2, 여기서 Bk는 자치시별 흑인의 비율',
       '모집단의 하위계층의 비율','본인 소유의 주택가격(중앙값,단위 $1,000)']
for i in range(len(housing_data['feature_names'])):
    col = housing_data['feature_names'][i]
    describe = DECR[i]
    print(f'{i+1:2d}번 :{col:7} ({describe})')
# Out:
# a번 정답
# 1. row 수는 506 이며 이는 observation, 즉 보스턴의 town 수 이다.
# 2. columns 수는 14 이며 이는 각 집의 특징이다.
#  1번 :CRIM    (자치시별 1인당 범죄율)
#  2번 :ZN      (25,000 평방피트를 초과하는 거주지역의 비율)
#  3번 :INDUS   (비소매상업지역이 점유하고 있는 토지의 비율)
#  4번 :CHAS    (찰스강에 대한 더미변수(강의 경계에 위치하면 1, 아니면 0))
#  5번 :NOX     (10ppm당 농축 일산화질소)
#  6번 :RM      (주태 1가구당 평균 방 개수)
#  7번 :AGE     (1940년 이전에 건축된 소유주택의 비율)
#  8번 :DIS     (5개의보스턴 직업센터까지의 접근성 지수)
#  9번 :RAD     (방사형 도로까지의 접근성 지수)
# 10번 :TAX     (10,000 달러 당 재산 세율)
# 11번 :PTRATIO (자치시별 학생/교사 비율)
# 12번 :B       (1000(Bk-0.63)^2, 여기서 Bk는 자치시별 흑인의 비율)
# 13번 :LSTAT   (모집단의 하위계층의 비율)

# %% [markdown]
# l

# %%
print('data의 스케일이 달라서 분석하는데 방해가 된다')
print('각 특징을, 평균이 0, 분산이 1로 정규화 시켜준다')
from sklearn.preprocessing import StandardScaler
str = StandardScaler()
x_scaled = str.fit_transform(x)
target_scaled = str.fit_transform(housing_data.target.reshape(-1,1))
Boston_scaled = pd.DataFrame(x_scaled,columns = housing_data['feature_names'])
Boston_scaled['MEDV']=target_scaled
Boston_scaled
# Out:
# data의 스케일이 달라서 분석하는데 방해가 된다
# 각 특징을, 평균이 0, 분산이 1로 정규화 시켜준다
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1   -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
# 2   -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714 -0.265812
# 3   -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303 -0.809889
# 4   -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577 -0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.115738 -0.272599  0.158124  0.439316  0.018673
# 502 -0.415249 -0.487722  0.115738 -0.272599  0.158124 -0.234548  0.288933
# 503 -0.413447 -0.487722  0.115738 -0.272599  0.158124  0.984960  0.797449
# 504 -0.407764 -0.487722  0.115738 -0.272599  0.158124  0.725672  0.736996
# 505 -0.415000 -0.487722  0.115738 -0.272599  0.158124 -0.362767  0.434732
#
# ...

# %%
Boston_scaled.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %% [markdown]
# ### b번 문제.  predictors 의 산점도 그래프를 그리고 관계성을 발견하기

# %% [markdown]
# #### 정규화 시키기 전 데이터로 산점도 그래프 그리기

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(Boston)
plt.show()

# %% [markdown]
# #### 정규화 시켜준 이후의 데이터로 산점도 그래프 그리기

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(Boston_scaled)
plt.show()

# %% [markdown]
# ### C번 문제.  per capita crime rate(1번특징)과 관계 있는 특징이 있는지? 이유는?

# %% [markdown]
# #### 정규화 시키기 전 데이터로 산점도 그래프 그리기

# %%
print('공분산 행렬을 구해보는 것도 관계성 확인에 좋을 것이다.')
print('공분산 행렬은 다음과 같다')
import numpy as np
Cov1 = np.cov(Boston.T)
Cov1 = pd.DataFrame(Cov1)
Cov1
# Out:
# 공분산 행렬을 구해보는 것도 관계성 확인에 좋을 것이다.
# 공분산 행렬은 다음과 같다
#              0            1           2         3          4          5  \
# 0    73.986578   -40.215956   23.992339 -0.122109   0.419594  -1.325038
# 1   -40.215956   543.936814  -85.412648 -0.252925  -1.396148   5.112513
# 2    23.992339   -85.412648   47.064442  0.109669   0.607074  -1.887957
# 3    -0.122109    -0.252925    0.109669  0.064513   0.002684   0.016285
# 4     0.419594    -1.396148    0.607074  0.002684   0.013428  -0.024603
# 5    -1.325038     5.112513   -1.887957  0.016285  -0.024603   0.493671
# 6    85.405322  -373.901548  124.513903  0.618571   2.385927  -4.751929
# 7    -6.876722    32.629304  -10.228097 -0.053043  -0.187696   0.303663
# 8    46.847761   -63.348695   35.549971 -0.016296   0.616929  -1.283815
# 9   844.821538 -1236.453735  833.360290 -1.523367  13.046286 -34.583448
# 10    5.399331   -19.776571    5.692104 -0.066819   0.047397  -0.540763
# ...

# %% [markdown]
# #### 정규화 시켜준 이후의 데이터로 공분산 행렬 구하기

# %%
Cov2 = np.cov(Boston_scaled.T)
Cov2 = pd.DataFrame(Cov2)
Cov2
# Out:
#            0         1         2         3         4         5         6  \
# 0   1.001980 -0.200866  0.407389 -0.056002  0.421805 -0.219681  0.353433
# 1  -0.200866  1.001980 -0.534885 -0.042781 -0.517627  0.312608 -0.570665
# 2   0.407389 -0.534885  1.001980  0.063063  0.765164 -0.392451  0.646055
# 3  -0.056002 -0.042781  0.063063  1.001980  0.091383  0.091432  0.086689
# 4   0.421805 -0.517627  0.765164  0.091383  1.001980 -0.302787  0.732919
# 5  -0.219681  0.312608 -0.392451  0.091432 -0.302787  1.001980 -0.240741
# 6   0.353433 -0.570665  0.646055  0.086689  0.732919 -0.240741  1.001980
# 7  -0.380422  0.665724 -0.709429 -0.099372 -0.770753  0.205653 -0.749361
# 8   0.626744 -0.312566  0.596308 -0.007383  0.612651 -0.210262  0.456925
# 9   0.583918 -0.315186  0.722187 -0.035657  0.669346 -0.292626  0.507458
# 10  0.290520 -0.392454  0.384006 -0.121756  0.189307 -0.356205  0.262033
# 11 -0.385826  0.175868 -0.357683  0.048885 -0.380803  0.128322 -0.274076
# ...

# %%
### d번 문제. 보스턴의 ㅊs of Boston appear to have particularly
high crime rates? Tax rates? Pupil-teacher ratios? Comment on
the range of each predictor.per capita crime rate(1번특징)과 관계 있는 특징이 있는지? 이유는?

# %%
def load_housing_data(housing_path=housing_path):
    csv_path = os.path.join(housing_path,'housing.csv')
    return pd.read_csv(csv_path)
    




                      
                               
#from sklearn.datasets import load_boston



from sklearn.datasets import load_boston

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

x = load_boston().data
columns=load_boston().feature_names
df = pd.DataFrame(x,columns=columns)

plt.show()
